# %%
import pandas as pd
from requests_html import HTMLSession

# %%
url = "https://www.liepin.com/zhaopin/"
session = HTMLSession()
#payload = 参数_compTag_用户体验['2018互联网300强']
参数_2018互联网300强_行业 = {}

参数_企业 = {}


r = session.get(url)
行业细分 = r.html.xpath("//div[@class='sub-industry']/a")

href_行业字典 = {a.xpath("a/text()")[0]: a.xpath("a/@href")[0]for a in 行业细分}

href_行业字典
# def requests_liepin( url, params):
#     r = session.get( url , params = payload)

#     # 先取特定元素, 精准打击其子后辈
#     #主要元素 = r.html.xpath( '//ul[@class='clearfix']/li/')

# //ul[@class="sojob-list"]/li
# 作为xpath字典，键为我要抓的牛肉名称，值为xpath
#    # dict_xpaths={
#         'text': {
#               '互联网电商':'//div[@class='sub-industry']/a[1]',
#               '游戏行业':'//div[@class='sub-industry']/a[2]',
#             '计算机':'//div[@class='sub-industry']/a[3]',
#     }
# Out:
# {'互联网/电商': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=040&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
#  '游戏产业': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=420&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
# ...

# %%
from urllib.parse import urlparse, parse_qs
import pandas as pd
from IPython.display import display, HTML

# %%
[urlparse(x) for x in href_行业字典.values()]
# Out:
# [ParseResult(scheme='', netloc='', path='/zhaopin/', params='', query='subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=040&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09', fragment=''),
#  ParseResult(scheme='', netloc='', path='/zhaopin/', params='', query='subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=420&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09', fragment=''),
# ...

# %%
href_行业字典
# Out:
# {'互联网/电商': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=040&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
#  '游戏产业': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=420&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
# ...

# %%
df = pd.DataFrame([urlparse(x) for x in href_行业字典.values()])
df.info()
print(df.nunique())
df.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   scheme    51 non-null     object
#  1   netloc    51 non-null     object
#  2   path      51 non-null     object
#  3   params    51 non-null     object
#  4   query     51 non-null     object
#  5   fragment  51 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB
# scheme       1
# netloc       1
# path         1
# params       1
# query       51
# fragment     1
# dtype: int64
#   scheme netloc       path params  \
# 0                /zhaopin/
#
#                                                query fragment
# 0  subIndustry=&init=-1&industryType=industry_01&...

# %%
href_行业字典
# Out:
# {'互联网/电商': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=040&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
#  '游戏产业': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=420&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
# ...

# %%
df_qs = pd.DataFrame([{k: v[0] for k, v in parse_qs(x).items()}
                      for x in df['query']])
print(df_qs.nunique())
df_qs.head()
df_qs[['industryType', 'industries']]
# Out:
# init              1
# industryType     12
# headckid          1
# flushckid         1
# fromSearchBtn     1
# industries       51
# ckid              1
# siTag             1
# d_sfrom           1
# d_ckId            1
# d_curPage         1
# d_pageSize        1
# d_headId          1
# dtype: int64
#    industryType industries
# 0   industry_01        040
# 1   industry_01        420
# 2   industry_01        010
# 3   industry_01        030
# 4   industry_02        050
# 5   industry_02        060
# 6   industry_02        020
# 7   industry_03        080
# 8   industry_03        100
# 9   industry_03        090
# 10  industry_04        130
# 11  industry_04        140
# 12  industry_04        150
# 13  industry_04        430
# 14  industry_04        500
# 15  industry_05        190
# 16  industry_05        240
# 17  industry_05        200
# 18  industry_05        210
# 19  industry_05        220
# 20  industry_05        460
# 21  industry_05        470
# 22  industry_06        350
# ...

# %%
href_行业字典
# Out:
# {'互联网/电商': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=040&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
#  '游戏产业': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3431ead914028ce6&flushckid=1&fromSearchBtn=2&industries=420&ckid=3431ead914028ce6&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=5c3e35a63997f023a6f0597290f82f09&d_curPage=0&d_pageSize=40&d_headId=5c3e35a63997f023a6f0597290f82f09',
# ...

# %%
# def parse_url (url):
#     f_parts = urlparse(url) 
#     out = parse_qs(f_parts.query)
#     return (out)

# %%
# #参数模板 = parse_url(行业字典[1])

# 参数模板 = parse_url(href_行业[0])
# print (参数模板)

# #print (href_字典)


def parse_url_qs_for_curPage (url):
    six_parts = urlparse(url) 
    out = parse_qs(six_parts.query)
    return (out)

# 取一例做模板
for i in href_行业字典():
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-86710b8999e6> in <module>
#      13
#      14 # 取一例做模板
# ---> 15 href_行业字典.key()
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
def 参数模板(industry, industries):
    参数 = parse_url(行业字典[：0])
# Out:
#   File "<ipython-input-52-5b231ed8e8c8>", line 2
#     参数 = parse_url(行业字典[：0])
#                          ^
# SyntaxError: invalid character in identifier
